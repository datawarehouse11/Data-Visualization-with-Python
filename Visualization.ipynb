# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
#Importing the required dataset
cars_df = pd.read_csv("Cars93.csv")
columns = ["Manufacturer","Model","Type","Price",
"MPG.city","MPG.highway","Horsepower","Rear.seat.room","Passengers"]
cars_df[columns].head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city  MPG.highway  Horsepower  \
# 0        Acura  Integra    Small   15.9        25           31         140
# 1        Acura   Legend  Midsize   33.9        18           25         200
# 2         Audi       90  Compact   29.1        20           26         172
# 3         Audi      100  Midsize   37.7        19           26         172
# 4          BMW     535i  Midsize   30.0        22           30         208
#
#    Rear.seat.room  Passengers
# 0            26.5           5
# 1            30.0           5
# 2            28.0           5
# 3            31.0           6
# 4            27.0           4

# %%
cars["Price"].plot(kind="box",figsize=(10,7))
# Out:
# <Axes: >

# %%
fig, (ax1,ax2) = plt.subplots(2,1)
fig.set_figwidth(10)
fig.set_figheight(7)

ax1.boxplot(cars['Horsepower'], vert=False)
ax2.boxplot(cars['MPG.city'], vert=False)

ax1.set_title("Horsepower")
ax1.set_xlabel("Horsepower")
ax2.set_title("City Milieage")
ax2.set_xlabel("City Milieage (in miles per US gallon)")

fig.tight_layout()

# %%
fig, ax = plt.subplots(2, 3)
fig.set_figwidth(10)
fig.set_figheight(7)

fig.suptitle("Multiple box plots", fontsize=16)

ax[0][0].boxplot(cars["Price"][cars["Type"]=="Compact"])
ax[0][0].set_title("Compact")
ax[0][1].boxplot(cars["Price"][cars["Type"]=="Large"])
ax[0][1].set_title("Large")
ax[0][2].boxplot(cars["Price"][cars["Type"]=="Midsize"])
ax[0][2].set_title("Midsize")
ax[1][0].boxplot(cars["Price"][cars["Type"]=="Small"])
ax[1][0].set_title("Small")
ax[1][1].boxplot(cars["Price"][cars["Type"]=="Sporty"])
ax[1][1].set_title("Sporty")
ax[1][2].boxplot(cars["Price"][cars["Type"]=="Van"])
ax[1][2].set_title("Van")
# Out:
# Text(0.5, 1.0, 'Van')

# %%
car_type_list = cars["Type"].unique()

fig, ax = plt.subplots()
fig.set_figwidth(10)
fig.set_figheight(7)

ax.boxplot([cars["Price"][cars["Type"]==k] for k in car_type_list])

plt.xticks([i for i in range(1, len(car_type_list)+1)],[k for k in car_type_list]) 

fig.suptitle("Prices of cars according to car type", fontsize=16, y=1)
# Out:
# Text(0.5, 1, 'Prices of cars according to car type')

# %%
fig, ax = plt.subplots(2, 3, sharey=True, sharex=True)
fig.set_figwidth(10)
fig.set_figheight(7)

fig.suptitle("Multiple box plots", fontsize=16)

ax[0][0].boxplot(cars["Price"][cars["Type"]=="Compact"])
ax[0][0].set_title("Compact")
ax[0][1].boxplot(cars["Price"][cars["Type"]=="Large"])
ax[0][1].set_title("Large")
ax[0][2].boxplot(cars["Price"][cars["Type"]=="Midsize"])
ax[0][2].set_title("Midsize")
ax[1][0].boxplot(cars["Price"][cars["Type"]=="Small"])
ax[1][0].set_title("Small")
ax[1][1].boxplot(cars["Price"][cars["Type"]=="Sporty"])
ax[1][1].set_title("Sporty")
ax[1][2].boxplot(cars["Price"][cars["Type"]=="Van"])
ax[1][2].set_title("Van")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21568\3511984376.py in ?()
#      16 ax[1][1].set_title("Sporty")
#      17 ax[1][2].boxplot(cars["Price"][cars["Type"]=="Van"])
#      18 ax[1][2].set_title("Van")
#      19
# ---> 20 cars["MPG.city"].plt(type="hist",figsize=(10,7), grid=True, bins=6)
#      21 plt.suptitle("Distribution of MPG.city", fontsize=16)
#      22 plt.legend()
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'plt'

# %%
import matplotlib.pyplot as plt
cars["MPG.city"].plot(kind="hist",figsize=(10,7), grid=True,bins=6)
plt.suptitle("Distribution of MPG.city", fontsize=16)
plt.legend()

# %%
import matplotlib.pyplot as plt
cars["MPG.city"].plot(kind="hist",figsize=(10,7),bins=20)
plt.suptitle("Distribution of MPG.city", fontsize=16)
plt.legend()

# %%
import matplotlib.pyplot as plt
cars["MPG.city"].plot(kind="hist",figsize=(10,7),bins=20, color="C1")
plt.suptitle("Distribution of MPG.city", fontsize=16)
plt.xticks(range(15,50))
plt.legend()

# %%
cars["MPG.city"].plot(kind='density')
cars["MPG.city"].plot(kind='hist', bins=15, density=True, figsize=(10,7))
plt.suptitle("Ditribution of MPG.city", fontsize=16)
plt.xlim(14,50)
# Out:
# (14.0, 50.0)

# %%
ax = cars.plot(["Horsepower"],["MPG.city"], kind="scatter", color="black",figsize=(10,7))

ax.set_xlabel("Horsepower")
ax.set_ylabel("MPG.size")
ax.set_title("Horsepower vs MPG.size,fontsize=16")
# Out:
# Text(0.5, 1.0, 'Horsepower vs MPG.size,fontsize=16')

# %%
ax = cars.plot(["Horsepower"],["MPG.city"], kind="scatter", marker="*", color="black",figsize=(10,7))

ax.set_xlabel("Horsepower")
ax.set_ylabel("MPG.size")
ax.set_title("Horsepower vs MPG.size,fontsize=16")
# Out:
# Text(0.5, 1.0, 'Horsepower vs MPG.size,fontsize=16')

# %%
ax = cars.plot(["Horsepower"],["MPG.city"], kind="scatter", marker="+", color="black",figsize=(10,7))

ax.set_xlabel("Horsepower")
ax.set_ylabel("MPG.size")
ax.set_title("Horsepower vs MPG.size,fontsize=16")
# Out:
# Text(0.5, 1.0, 'Horsepower vs MPG.size,fontsize=16')

# %%
import matplotlib.pyplot as plt
from matplotlib import colormaps as cm
import numpy as np


fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(7)

colors = cm.seismic_r(np.linespace(0,1,len(car_type_list)))

for car_type,c in zap(car_type_list, colors):
    y = cars[cars["Type"] == car_type]["Horsepower"]
    x = cars[cars["Type"] == car_type]["MPG.size"]
    plt.scatter(x,y,color = c, label=car_type)

plt.suptitle("Scatter plot of Horsepower and millieage", fontsize=16)
plt.xlabel("Horsepower")
plt.ylabel("MPG.size")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 10
#       7 fig.set_figwidth(10)
#       8 fig.set_figheight(7)
# ---> 10 colors = cm.seismic_r(np.linespace(0,1,len(car_type_list)))
#      12 for car_type,c in zap(car_type_list, colors):
#      13     y = cars[cars["Type"] == car_type]["Horsepower"]
#
# AttributeError: 'ColormapRegistry' object has no attribute 'seismic_r'

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

cars = pd.read_csv("Cars93.csv")
car_type_list = cars["Type"].unique()
fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(7)
colors = plt.cm.seismic_r(np.linspace(0, 1, len(car_type_list))) # We extract the colours using the 'seismic_r' method. Here, 'r' indicates the reverse.
for car_type,c in zip(car_type_list,colors): 	# for every car type in the car_type_list we plot all the points in the scatter plot
    x = cars_df[cars_df["Type"] == car_type]["Horsepower"]
    y = cars_df[cars_df["Type"] == car_type]["MPG.city"]
    plt.scatter(x,y,color = c,label=car_type)
plt.suptitle("Scatter plot of horsepower and mileage",fontsize=16)
plt.xlabel("Horsepower")
plt.ylabel("Mileage City")
plt.legend()

# %%
fig, ax = plt.subplots(figsize=(25, 20))
# Create the bubble chart
ax.scatter(cars_df['Price'],cars_df['MPG.city'], s=cars_df['EngineSize']*100,alpha=0.5)
# Set the labels and title
ax.set_xlabel('Price')
ax.set_ylabel('City MPG')
ax.set_title('Relationship between the city MPG, price, and engine size of cars')
#fig.tight_layout()
# Out:
# Text(0.5, 1.0, 'Relationship between the city MPG, price, and engine size of cars')

# %%
fig, ax = plt.subplots(figsize=(25,20))

for i, row in cars.iterrows():
    ax.scatter(row["Price"],row["MPG.city"], s=row["EngineSize"]*100,alpha=0.5)
    ax.annotate(row['Manufacturer'],(row['Price'],row['MPG.city']), ha='center', va='center')

ax.set_xlabel("Price")
ax.set_ylabel("MPG.city")
ax.set_title("Relationship between MPG.city, price and engine size between cars")

fig.tight_layout()

# %%
fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(7)

plt.bar(cars["DriveTrain"],cars["MPG.city"],width=0.2,label="Milleage in city")

plt.suptitle("DriveTrain vs MPG.city", fontsize=16)
plt.xlabel("DriveTrain")
plt.ylabel("MPG.city")

plt.legend()

# %%
cars["Passengers"].unique()
# Out:
# array([5, 6, 4, 7, 8, 2])

# %%
cars["Type"].unique()
# Out:
# array(['Small', 'Midsize', 'Compact', 'Large', 'Sporty', 'Van'],
#       dtype=object)

# %%
grouped_data = cars[["Passengers", "Type"]].groupby(by = ["Passengers", "Type"]).size().unstack().reset_index()

# %%
grouped_data.plot(x="Passengers",kind="bar", stacked=True, colormap=plt.cm.Paired, figsize=(10,7))
# Out:
# <Axes: xlabel='Passengers'>

# %%
grouped_data.plot(x="Passengers",kind="bar", stacked=True, colormap=plt.cm.seismic, figsize=(10,7), yerr=np.std(cars["Passengers"]))
# Out:
# <Axes: xlabel='Passengers'>

# %%
cars["DriveTrain"].unique()
# Out:
# array(['Front', 'Rear', '4WD'], dtype=object)

# %%
grouped_cars = cars[["MPG.city","MPG.highway","RPM","DriveTrain"]].groupby(by="DriveTrain").mean().T
grouped_cars
# Out:
# DriveTrain      4WD        Front       Rear
# MPG.city       20.5    23.522388    18.6875
# MPG.highway    25.8    30.238806    26.3125
# RPM          5120.0  5374.626866  4987.5000

# %%
fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(7)

grouped_cars.loc["RPM"]/=100
width = 0.2
ind=list(range(len(cars["DriveTrain"].unique())))

plt.bar([i for i in ind], height=grouped_cars["4WD"],label="4WD", width=width)
plt.bar([i+width for i in ind], height=grouped_cars["Front"], width=width, bottom=0, label="Front")
plt.bar([i+width*2 for i in ind], height=grouped_cars["Rear"], label="Rear", bottom=0, width=width)

plt.suptitle("Mileage in city, Mileage on highway,RPM vs DriveTrain", fontsize=16)
plt.xlabel("Mileage in city, Mileage in highway, RPM")
plt.ylabel("Average per DriveTrain type")
plt.xticks([i+width for i in ind],["Mileage in City","Mileage in Highway","RPM"])
plt.legend()

# %%
cars = cars.sort_values(by="Horsepower")

fig, ax = plt.subplots()
fig.set_figwidth(10)
fig.set_figheight(7)

cars.plot(ax=ax,x="Horsepower", y="MPG.highway", kind="line")
cars.plot(ax=ax,x="Horsepower", y="MPG.city", kind="line", linestyle="--")
# Out:
# <Axes: xlabel='Horsepower'>

# %%
cars = cars.sort_values(by="Horsepower")

fig, ax = plt.subplots()
fig.set_figwidth(10)
fig.set_figheight(7)

cars.plot(ax=ax,x="Horsepower", y="MPG.highway", kind="line")
cars.plot(ax=ax,x="Horsepower", y="MPG.city", kind="line", linestyle="--")

ax.set_ylabel("Mileage in (mile per US gallon)")
ax.set_title("Mileage vs Horsepower",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Mileage vs Horsepower')

# %%
cars = cars.sort_values(by="Horsepower")

fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(7)

plt.plot(cars["Horsepower"],cars["MPG.city"], label="MPG.city")
plt.plot(cars["Horsepower"],cars["EngineSize"], label="EngineSize")
plt.plot(cars["Horsepower"],cars["MPG.highway"], label="MPG.highway")
plt.plot(cars["Horsepower"],[i/100 for i in cars["RPM"]], label="RPM")

plt.suptitle("Horsepower vs Mileage in city, Engine size, Mileage on highway, RPM",fontsize=16)
plt.xlabel("Horsepower")
plt.ylabel("Mileage in city, Engine size, Mileage on highway, RPM")
plt.legend()

# %%
fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(9)
plt.plot(cars_df["MPG.city"],cars_df["Horsepower"],label="MPG.city")
plt.plot(cars_df["EngineSize"],cars_df["Horsepower"],label="Engine Size")
plt.plot(cars_df["MPG.highway"],cars_df["Horsepower"],label="MPG.highway")
plt.plot([i/100 for i in cars_df["RPM"]],cars_df["Horsepower"],label="RPM") #interchanging x and y
plt.suptitle("Mileage in city, Engine size, Mileage on highway, RPM vs Horsepower",fontsize=15)
plt.ylabel("Horsepower")
plt.xlabel("Mileage in city, Engine size, Mileage on highway, RPM")
plt.legend()

# %%
origin_counts = cars["Origin"].value_counts()
origin_counts
# Out:
# Origin
# USA        48
# non-USA    45
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots()
ax.pie(origin_counts.values, labels=origin_counts.index, autopct='%1.1f%%', startangle=90)
ax.set_title("Cars by origin")
plt.show()

# %%
cars_df["Cylinders"].unique() 
grouped_data = cars_df[[ "Cylinders", "Type"]].groupby(by = [ "Cylinders", "Type"]).size().unstack()

fig, ax = plt.subplots(2,3, figsize = (15,10))
grouped_data.plot.pie(ax = ax, subplots = True, fontsize = 30,autopct=lambda p: '{:.2f}%'.format(round(p)) if p > 0 else'')
fig.suptitle("Number of cylinders for each type of car", fontsize=30, x = 1, y = 2.1)
fig.tight_layout
# Out:
# <bound method Figure.tight_layout of <Figure size 1500x1000 with 6 Axes>>

# %%
diabetes = pd.read_csv("diabetes.csv")
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import seaborn as sns
sns.histplot(diabetes["BMI"], kde=False)

plt.title("Distrobution of BMI")
plt.xlabel("BMI")
plt.ylabel("Count")
plt.show()

# %%
# Create density plot 
#sns.kdeplot(diabetes[diabetes['Outcome']==0]['BloodPressure'], label='No Diabetes')
#Uncomment the above line for comparing diabetes and no-diabetes
sns.kdeplot(diabetes[diabetes['Outcome']==1]['BloodPressure'], label='Diabetes')
plt.title('Density Plot of Blood Pressure by Diabetes Status')
plt.xlabel('Blood Pressure')
plt.ylabel('Density')
plt.legend()
plt.show()
